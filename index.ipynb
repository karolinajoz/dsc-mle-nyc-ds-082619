# %% [markdown]
# # Maximum Likelihood Estimation (MLE)
#
# ## Introduction
#
# "Parameter Inference" is one of the most important concepts of predictive machine learning. In this lesson, you will begin to build an intuition surrounding the ideas around this concept. You'll first look at the maximum likelihood estimation (MLE) for the posterior probability based on observed data. (A direct application of Bayes Theorem.) From there, you'll conduct a random experiment involving a series of coin tosses to derive the general formula for MLE of a binomial distribution.
#
# ## Objectives
#
# You will be able to:
# * Understand and describe parametric inference based in context of identifying optimal values for model parameters
# * Understand the concept of likelihood , and the difference between likelihood and a probability
# * Describe MLE assumption of IID samples and its implications on model development
#
# ## Parameter Inference
#
# Parameter Inference is the process of probabilistically inferring parameter(s) for a model of our choice, that is which parameter values best describe the underlying dataset, used in an analytical context. Let's try to understand this with a simple experiment with a 10 times coin flip and inspecting the outcome.

# %%
import random
def coinToss():
    number = int(input("Number of times to flip coin: "))
    recordList = []
    heads = 0
    tails = 0
    for amount in range(number):
         flip = random.randint(0, 1)
         if (flip == 0):
              print("Toss", amount+1 ,':' , "Heads")
              recordList.append("Heads")
         else:
              print("Toss", amount+1 ,':' , "Tails")
              recordList.append("Tails")
    print(str(recordList))
    print(str(recordList.count("Heads")) + str(recordList.count("Tails")))
    return recordList

# %%
lst = coinToss()
# Out:
# Number of times to flip coin: 1000
# Toss 1 : Heads
# Toss 2 : Heads
# Toss 3 : Heads
# Toss 4 : Tails
# Toss 5 : Heads
# Toss 6 : Tails
# Toss 7 : Heads
# Toss 8 : Heads
# Toss 9 : Heads
# Toss 10 : Tails
# Toss 11 : Heads
# Toss 12 : Tails
# Toss 13 : Heads
# Toss 14 : Heads
# Toss 15 : Heads
# Toss 16 : Heads
# Toss 17 : Heads
# Toss 18 : Tails
# Toss 19 : Heads
# Toss 20 : Heads
# Toss 21 : Tails
# Toss 22 : Tails
# Toss 23 : Heads
# Toss 24 : Tails
# Toss 25 : Heads
# Toss 26 : Tails
# Toss 27 : Heads
# Toss 28 : Tails
# Toss 29 : Tails
# Toss 30 : Heads
# Toss 31 : Heads
# Toss 32 : Heads
# Toss 33 : Heads
# Toss 34 : Heads
# Toss 35 : Tails
# Toss 36 : Tails
# Toss 37 : Tails
# Toss 38 : Heads
# Toss 39 : Heads
# Toss 40 : Heads
# Toss 41 : Tails
# Toss 42 : Heads
# Toss 43 : Heads
# Toss 44 : Heads
# Toss 45 : Tails
# Toss 46 : Tails
# Toss 47 : Heads
# Toss 48 : Heads
# Toss 49 : Heads
# Toss 50 : Heads
# Toss 51 : Heads
# Toss 52 : Heads
# Toss 53 : Tails
# Toss 54 : Heads
# Toss 55 : Heads
# Toss 56 : Tails
# Toss 57 : Tails
# Toss 58 : Heads
# Toss 59 : Tails
# Toss 60 : Heads
# Toss 61 : Heads
# Toss 62 : Tails
# Toss 63 : Heads
# Toss 64 : Tails
# Toss 65 : Tails
# Toss 66 : Heads
# Toss 67 : Heads
# Toss 68 : Tails
# Toss 69 : Tails
# Toss 70 : Tails
# Toss 71 : Tails
# Toss 72 : Tails
# Toss 73 : Tails
# Toss 74 : Tails
# Toss 75 : Tails
# Toss 76 : Tails
# Toss 77 : Tails
# Toss 78 : Tails
# Toss 79 : Tails
# Toss 80 : Heads
# Toss 81 : Heads
# Toss 82 : Heads
# Toss 83 : Tails
# Toss 84 : Tails
# Toss 85 : Heads
# Toss 86 : Tails
# Toss 87 : Heads
# Toss 88 : Tails
# Toss 89 : Heads
# Toss 90 : Tails
# Toss 91 : Tails
# Toss 92 : Heads
# Toss 93 : Tails
# Toss 94 : Heads
# Toss 95 : Tails
# Toss 96 : Tails
# Toss 97 : Tails
# Toss 98 : Tails
# Toss 99 : Heads
# Toss 100 : Tails
# Toss 101 : Tails
# Toss 102 : Tails
# Toss 103 : Heads
# Toss 104 : Heads
# Toss 105 : Tails
# Toss 106 : Heads
# Toss 107 : Heads
# Toss 108 : Heads
# Toss 109 : Tails
# Toss 110 : Tails
# Toss 111 : Tails
# Toss 112 : Heads
# Toss 113 : Heads
# Toss 114 : Tails
# Toss 115 : Tails
# Toss 116 : Heads
# Toss 117 : Heads
# Toss 118 : Heads
# Toss 119 : Heads
# Toss 120 : Heads
# Toss 121 : Tails
# Toss 122 : Tails
# Toss 123 : Heads
# Toss 124 : Tails
# Toss 125 : Tails
# Toss 126 : Heads
# Toss 127 : Heads
# Toss 128 : Tails
# Toss 129 : Tails
# Toss 130 : Heads
# Toss 131 : Heads
# Toss 132 : Tails
# Toss 133 : Tails
# Toss 134 : Heads
# Toss 135 : Heads
# Toss 136 : Heads
# Toss 137 : Heads
# Toss 138 : Tails
# Toss 139 : Tails
# Toss 140 : Heads
# Toss 141 : Heads
# Toss 142 : Heads
# Toss 143 : Tails
# Toss 144 : Heads
# Toss 145 : Heads
# Toss 146 : Heads
# Toss 147 : Heads
# Toss 148 : Tails
# Toss 149 : Heads
# Toss 150 : Heads
# Toss 151 : Tails
# Toss 152 : Tails
# Toss 153 : Heads
# Toss 154 : Tails
# Toss 155 : Tails
# Toss 156 : Heads
# Toss 157 : Tails
# Toss 158 : Heads
# Toss 159 : Heads
# Toss 160 : Tails
# Toss 161 : Tails
# Toss 162 : Tails
# Toss 163 : Heads
# Toss 164 : Tails
# Toss 165 : Heads
# Toss 166 : Tails
# Toss 167 : Heads
# Toss 168 : Heads
# Toss 169 : Tails
# Toss 170 : Heads
# Toss 171 : Heads
# Toss 172 : Tails
# Toss 173 : Tails
# Toss 174 : Heads
# Toss 175 : Heads
# Toss 176 : Heads
# Toss 177 : Tails
# Toss 178 : Heads
# Toss 179 : Heads
# Toss 180 : Heads
# Toss 181 : Heads
# Toss 182 : Tails
# Toss 183 : Tails
# Toss 184 : Tails
# Toss 185 : Heads
# Toss 186 : Heads
# Toss 187 : Heads
# Toss 188 : Heads
# Toss 189 : Heads
# Toss 190 : Tails
# Toss 191 : Tails
# Toss 192 : Tails
# Toss 193 : Tails
# Toss 194 : Heads
# Toss 195 : Heads
# Toss 196 : Tails
# Toss 197 : Heads
# Toss 198 : Heads
# Toss 199 : Heads
# Toss 200 : Heads
# Toss 201 : Tails
# Toss 202 : Tails
# Toss 203 : Heads
# Toss 204 : Heads
# Toss 205 : Heads
# Toss 206 : Heads
# Toss 207 : Heads
# Toss 208 : Tails
# Toss 209 : Heads
# Toss 210 : Tails
# Toss 211 : Heads
# Toss 212 : Tails
# Toss 213 : Heads
# Toss 214 : Tails
# Toss 215 : Tails
# Toss 216 : Tails
# Toss 217 : Tails
# Toss 218 : Heads
# Toss 219 : Tails
# Toss 220 : Heads
# Toss 221 : Tails
# Toss 222 : Tails
# Toss 223 : Heads
# Toss 224 : Heads
# Toss 225 : Tails
# Toss 226 : Heads
# Toss 227 : Tails
# Toss 228 : Heads
# Toss 229 : Tails
# Toss 230 : Tails
# Toss 231 : Heads
# Toss 232 : Tails
# Toss 233 : Heads
# Toss 234 : Tails
# Toss 235 : Heads
# Toss 236 : Tails
# Toss 237 : Heads
# Toss 238 : Tails
# Toss 239 : Heads
# Toss 240 : Heads
# Toss 241 : Heads
# Toss 242 : Heads
# Toss 243 : Heads
# Toss 244 : Tails
# Toss 245 : Tails
# Toss 246 : Tails
# Toss 247 : Tails
# Toss 248 : Heads
# Toss 249 : Heads
# Toss 250 : Heads
# Toss 251 : Heads
# Toss 252 : Tails
# Toss 253 : Tails
# Toss 254 : Heads
# Toss 255 : Heads
# Toss 256 : Tails
# Toss 257 : Tails
# Toss 258 : Heads
# Toss 259 : Heads
# Toss 260 : Tails
# Toss 261 : Heads
# Toss 262 : Tails
# Toss 263 : Heads
# Toss 264 : Tails
# Toss 265 : Tails
# Toss 266 : Tails
# Toss 267 : Heads
# Toss 268 : Heads
# Toss 269 : Tails
# Toss 270 : Tails
# Toss 271 : Heads
# Toss 272 : Heads
# Toss 273 : Heads
# Toss 274 : Heads
# Toss 275 : Tails
# Toss 276 : Heads
# Toss 277 : Heads
# Toss 278 : Heads
# Toss 279 : Tails
# Toss 280 : Heads
# Toss 281 : Heads
# Toss 282 : Tails
# Toss 283 : Tails
# Toss 284 : Tails
# Toss 285 : Heads
# Toss 286 : Tails
# Toss 287 : Heads
# Toss 288 : Heads
# Toss 289 : Heads
# Toss 290 : Heads
# Toss 291 : Heads
# Toss 292 : Tails
# Toss 293 : Tails
# Toss 294 : Heads
# Toss 295 : Heads
# Toss 296 : Heads
# Toss 297 : Tails
# Toss 298 : Tails
# Toss 299 : Tails
# Toss 300 : Heads
# Toss 301 : Heads
# Toss 302 : Tails
# Toss 303 : Heads
# Toss 304 : Tails
# Toss 305 : Heads
# Toss 306 : Tails
# Toss 307 : Heads
# Toss 308 : Tails
# Toss 309 : Heads
# Toss 310 : Heads
# Toss 311 : Heads
# Toss 312 : Heads
# Toss 313 : Tails
# Toss 314 : Tails
# Toss 315 : Tails
# Toss 316 : Heads
# Toss 317 : Tails
# Toss 318 : Heads
# Toss 319 : Tails
# Toss 320 : Heads
# Toss 321 : Heads
# Toss 322 : Heads
# Toss 323 : Tails
# Toss 324 : Tails
# Toss 325 : Heads
# Toss 326 : Tails
# Toss 327 : Tails
# Toss 328 : Tails
# Toss 329 : Heads
# Toss 330 : Tails
# Toss 331 : Heads
# Toss 332 : Heads
# Toss 333 : Heads
# Toss 334 : Tails
# Toss 335 : Tails
# Toss 336 : Tails
# Toss 337 : Tails
# Toss 338 : Tails
# Toss 339 : Tails
# Toss 340 : Heads
# Toss 341 : Tails
# Toss 342 : Tails
# Toss 343 : Tails
# Toss 344 : Tails
# Toss 345 : Tails
# Toss 346 : Tails
# Toss 347 : Heads
# Toss 348 : Tails
# Toss 349 : Heads
# Toss 350 : Heads
# Toss 351 : Heads
# Toss 352 : Heads
# Toss 353 : Tails
# Toss 354 : Heads
# Toss 355 : Tails
# Toss 356 : Tails
# Toss 357 : Tails
# Toss 358 : Tails
# Toss 359 : Tails
# Toss 360 : Heads
# Toss 361 : Tails
# Toss 362 : Tails
# Toss 363 : Heads
# Toss 364 : Heads
# Toss 365 : Tails
# Toss 366 : Tails
# Toss 367 : Tails
# Toss 368 : Tails
# Toss 369 : Tails
# Toss 370 : Heads
# Toss 371 : Tails
# Toss 372 : Tails
# Toss 373 : Tails
# Toss 374 : Tails
# Toss 375 : Heads
# Toss 376 : Tails
# Toss 377 : Heads
# Toss 378 : Heads
# Toss 379 : Heads
# Toss 380 : Heads
# Toss 381 : Tails
# Toss 382 : Tails
# Toss 383 : Heads
# Toss 384 : Tails
# Toss 385 : Heads
# Toss 386 : Tails
# Toss 387 : Heads
# Toss 388 : Heads
# Toss 389 : Tails
# Toss 390 : Heads
# Toss 391 : Heads
# Toss 392 : Heads
# Toss 393 : Tails
# Toss 394 : Tails
# Toss 395 : Tails
# Toss 396 : Heads
# Toss 397 : Heads
# Toss 398 : Tails
# Toss 399 : Heads
# Toss 400 : Tails
# Toss 401 : Tails
# Toss 402 : Tails
# Toss 403 : Heads
# Toss 404 : Tails
# Toss 405 : Heads
# Toss 406 : Heads
# Toss 407 : Heads
# Toss 408 : Tails
# Toss 409 : Tails
# Toss 410 : Heads
# Toss 411 : Tails
# Toss 412 : Tails
# Toss 413 : Heads
# Toss 414 : Heads
# Toss 415 : Tails
# Toss 416 : Heads
# Toss 417 : Tails
# Toss 418 : Tails
# Toss 419 : Heads
# Toss 420 : Tails
# Toss 421 : Heads
# Toss 422 : Tails
# Toss 423 : Tails
# Toss 424 : Tails
# Toss 425 : Tails
# Toss 426 : Heads
# Toss 427 : Tails
# Toss 428 : Tails
# Toss 429 : Heads
# Toss 430 : Tails
# Toss 431 : Tails
# Toss 432 : Tails
# Toss 433 : Heads
# Toss 434 : Tails
# Toss 435 : Heads
# Toss 436 : Tails
# Toss 437 : Heads
# Toss 438 : Tails
# Toss 439 : Heads
# Toss 440 : Tails
# Toss 441 : Heads
# Toss 442 : Heads
# Toss 443 : Heads
# Toss 444 : Heads
# Toss 445 : Heads
# Toss 446 : Tails
# Toss 447 : Tails
# Toss 448 : Heads
# Toss 449 : Heads
# Toss 450 : Tails
# Toss 451 : Heads
# Toss 452 : Heads
# Toss 453 : Heads
# Toss 454 : Tails
# Toss 455 : Heads
# Toss 456 : Heads
# Toss 457 : Heads
# Toss 458 : Tails
# Toss 459 : Heads
# Toss 460 : Heads
# Toss 461 : Heads
# Toss 462 : Tails
# Toss 463 : Tails
# Toss 464 : Heads
# Toss 465 : Tails
# Toss 466 : Heads
# Toss 467 : Tails
# Toss 468 : Heads
# Toss 469 : Tails
# Toss 470 : Tails
# Toss 471 : Heads
# Toss 472 : Heads
# Toss 473 : Tails
# Toss 474 : Tails
# Toss 475 : Heads
# Toss 476 : Tails
# Toss 477 : Tails
# Toss 478 : Tails
# Toss 479 : Tails
# Toss 480 : Heads
# Toss 481 : Heads
# Toss 482 : Heads
# Toss 483 : Heads
# Toss 484 : Tails
# Toss 485 : Heads
# Toss 486 : Heads
# Toss 487 : Tails
# Toss 488 : Tails
# Toss 489 : Heads
# Toss 490 : Tails
# Toss 491 : Tails
# Toss 492 : Tails
# Toss 493 : Heads
# Toss 494 : Tails
# Toss 495 : Tails
# Toss 496 : Heads
# Toss 497 : Tails
# Toss 498 : Heads
# Toss 499 : Heads
# Toss 500 : Heads
# Toss 501 : Heads
# Toss 502 : Heads
# Toss 503 : Heads
# Toss 504 : Tails
# Toss 505 : Tails
# Toss 506 : Tails
# Toss 507 : Heads
# Toss 508 : Tails
# Toss 509 : Tails
# Toss 510 : Heads
# Toss 511 : Tails
# Toss 512 : Heads
# Toss 513 : Tails
# Toss 514 : Tails
# Toss 515 : Tails
# Toss 516 : Heads
# Toss 517 : Tails
# Toss 518 : Heads
# Toss 519 : Tails
# Toss 520 : Tails
# Toss 521 : Tails
# Toss 522 : Tails
# Toss 523 : Tails
# Toss 524 : Tails
# Toss 525 : Heads
# Toss 526 : Heads
# Toss 527 : Heads
# Toss 528 : Heads
# Toss 529 : Heads
# Toss 530 : Heads
# Toss 531 : Tails
# Toss 532 : Heads
# Toss 533 : Tails
# Toss 534 : Tails
# Toss 535 : Heads
# Toss 536 : Tails
# Toss 537 : Heads
# Toss 538 : Heads
# Toss 539 : Heads
# Toss 540 : Tails
# Toss 541 : Tails
# Toss 542 : Heads
# Toss 543 : Tails
# Toss 544 : Tails
# Toss 545 : Heads
# Toss 546 : Tails
# Toss 547 : Heads
# Toss 548 : Tails
# Toss 549 : Tails
# Toss 550 : Heads
# Toss 551 : Tails
# Toss 552 : Heads
# Toss 553 : Tails
# Toss 554 : Heads
# Toss 555 : Heads
# Toss 556 : Heads
# Toss 557 : Heads
# Toss 558 : Tails
# Toss 559 : Tails
# Toss 560 : Heads
# Toss 561 : Heads
# Toss 562 : Tails
# Toss 563 : Tails
# Toss 564 : Tails
# Toss 565 : Tails
# Toss 566 : Tails
# Toss 567 : Heads
# Toss 568 : Heads
# Toss 569 : Heads
# Toss 570 : Heads
# Toss 571 : Heads
# Toss 572 : Tails
# Toss 573 : Tails
# Toss 574 : Tails
# Toss 575 : Tails
# Toss 576 : Heads
# Toss 577 : Tails
# Toss 578 : Tails
# Toss 579 : Heads
# Toss 580 : Heads
# Toss 581 : Heads
# Toss 582 : Heads
# Toss 583 : Heads
# Toss 584 : Heads
# Toss 585 : Heads
# Toss 586 : Heads
# Toss 587 : Tails
# Toss 588 : Heads
# Toss 589 : Tails
# Toss 590 : Tails
# Toss 591 : Tails
# Toss 592 : Tails
# Toss 593 : Heads
# Toss 594 : Tails
# Toss 595 : Tails
# Toss 596 : Heads
# Toss 597 : Tails
# Toss 598 : Tails
# Toss 599 : Heads
# Toss 600 : Heads
# Toss 601 : Heads
# Toss 602 : Heads
# Toss 603 : Heads
# Toss 604 : Heads
# Toss 605 : Tails
# Toss 606 : Tails
# Toss 607 : Tails
# Toss 608 : Tails
# Toss 609 : Heads
# Toss 610 : Heads
# Toss 611 : Heads
# Toss 612 : Tails
# Toss 613 : Heads
# Toss 614 : Heads
# Toss 615 : Tails
# Toss 616 : Tails
# Toss 617 : Heads
# Toss 618 : Tails
# Toss 619 : Heads
# Toss 620 : Tails
# Toss 621 : Heads
# Toss 622 : Heads
# Toss 623 : Heads
# Toss 624 : Heads
# Toss 625 : Heads
# Toss 626 : Heads
# Toss 627 : Tails
# Toss 628 : Heads
# Toss 629 : Tails
# Toss 630 : Heads
# Toss 631 : Heads
# Toss 632 : Heads
# Toss 633 : Tails
# Toss 634 : Tails
# Toss 635 : Tails
# Toss 636 : Tails
# Toss 637 : Tails
# Toss 638 : Heads
# Toss 639 : Tails
# Toss 640 : Heads
# Toss 641 : Tails
# Toss 642 : Heads
# Toss 643 : Heads
# Toss 644 : Heads
# Toss 645 : Heads
# Toss 646 : Tails
# Toss 647 : Tails
# Toss 648 : Heads
# Toss 649 : Heads
# Toss 650 : Heads
# Toss 651 : Heads
# Toss 652 : Heads
# Toss 653 : Tails
# Toss 654 : Tails
# Toss 655 : Tails
# Toss 656 : Heads
# Toss 657 : Heads
# Toss 658 : Heads
# Toss 659 : Tails
# Toss 660 : Tails
# Toss 661 : Heads
# Toss 662 : Heads
# Toss 663 : Heads
# Toss 664 : Tails
# Toss 665 : Heads
# Toss 666 : Heads
# Toss 667 : Heads
# Toss 668 : Heads
# Toss 669 : Heads
# Toss 670 : Heads
# Toss 671 : Tails
# Toss 672 : Heads
# Toss 673 : Tails
# Toss 674 : Tails
# Toss 675 : Heads
# Toss 676 : Heads
# Toss 677 : Tails
# Toss 678 : Tails
# Toss 679 : Heads
# Toss 680 : Heads
# Toss 681 : Heads
# Toss 682 : Tails
# Toss 683 : Tails
# Toss 684 : Heads
# Toss 685 : Tails
# Toss 686 : Heads
# Toss 687 : Tails
# Toss 688 : Tails
# Toss 689 : Heads
# Toss 690 : Heads
# Toss 691 : Tails
# Toss 692 : Heads
# Toss 693 : Heads
# Toss 694 : Tails
# Toss 695 : Heads
# Toss 696 : Heads
# Toss 697 : Tails
# Toss 698 : Tails
# Toss 699 : Tails
# Toss 700 : Tails
# Toss 701 : Tails
# Toss 702 : Heads
# Toss 703 : Heads
# Toss 704 : Heads
# Toss 705 : Tails
# Toss 706 : Heads
# Toss 707 : Heads
# Toss 708 : Heads
# Toss 709 : Tails
# Toss 710 : Tails
# Toss 711 : Heads
# Toss 712 : Heads
# Toss 713 : Heads
# Toss 714 : Tails
# Toss 715 : Tails
# Toss 716 : Heads
# Toss 717 : Heads
# Toss 718 : Tails
# Toss 719 : Tails
# Toss 720 : Heads
# Toss 721 : Tails
# Toss 722 : Heads
# Toss 723 : Heads
# Toss 724 : Heads
# Toss 725 : Tails
# Toss 726 : Heads
# Toss 727 : Tails
# Toss 728 : Heads
# Toss 729 : Tails
# Toss 730 : Heads
# Toss 731 : Heads
# Toss 732 : Heads
# Toss 733 : Tails
# Toss 734 : Heads
# Toss 735 : Heads
# Toss 736 : Heads
# Toss 737 : Heads
# Toss 738 : Heads
# Toss 739 : Tails
# Toss 740 : Heads
# Toss 741 : Heads
# Toss 742 : Tails
# Toss 743 : Tails
# Toss 744 : Heads
# Toss 745 : Tails
# Toss 746 : Heads
# Toss 747 : Heads
# Toss 748 : Heads
# Toss 749 : Tails
# Toss 750 : Heads
# Toss 751 : Heads
# Toss 752 : Tails
# Toss 753 : Tails
# Toss 754 : Heads
# Toss 755 : Tails
# Toss 756 : Tails
# Toss 757 : Tails
# Toss 758 : Tails
# Toss 759 : Tails
# Toss 760 : Tails
# Toss 761 : Tails
# Toss 762 : Tails
# Toss 763 : Heads
# Toss 764 : Tails
# Toss 765 : Heads
# Toss 766 : Tails
# Toss 767 : Heads
# Toss 768 : Heads
# Toss 769 : Tails
# Toss 770 : Heads
# Toss 771 : Tails
# Toss 772 : Tails
# Toss 773 : Heads
# Toss 774 : Heads
# Toss 775 : Heads
# Toss 776 : Tails
# Toss 777 : Heads
# Toss 778 : Heads
# Toss 779 : Tails
# Toss 780 : Heads
# Toss 781 : Tails
# Toss 782 : Heads
# Toss 783 : Tails
# Toss 784 : Tails
# Toss 785 : Heads
# Toss 786 : Heads
# Toss 787 : Heads
# Toss 788 : Heads
# Toss 789 : Heads
# Toss 790 : Tails
# Toss 791 : Tails
# Toss 792 : Heads
# Toss 793 : Heads
# Toss 794 : Heads
# Toss 795 : Heads
# Toss 796 : Heads
# Toss 797 : Tails
# Toss 798 : Tails
# Toss 799 : Tails
# Toss 800 : Heads
# Toss 801 : Tails
# Toss 802 : Heads
# Toss 803 : Tails
# Toss 804 : Tails
# Toss 805 : Tails
# Toss 806 : Tails
# Toss 807 : Heads
# Toss 808 : Tails
# Toss 809 : Tails
# Toss 810 : Heads
# Toss 811 : Tails
# Toss 812 : Heads
# Toss 813 : Tails
# Toss 814 : Tails
# Toss 815 : Tails
# Toss 816 : Tails
# Toss 817 : Heads
# Toss 818 : Tails
# Toss 819 : Heads
# Toss 820 : Tails
# Toss 821 : Tails
# Toss 822 : Heads
# Toss 823 : Heads
# Toss 824 : Heads
# Toss 825 : Tails
# Toss 826 : Tails
# Toss 827 : Tails
# Toss 828 : Heads
# Toss 829 : Tails
# Toss 830 : Heads
# Toss 831 : Tails
# Toss 832 : Tails
# Toss 833 : Heads
# Toss 834 : Tails
# Toss 835 : Heads
# Toss 836 : Tails
# Toss 837 : Heads
# Toss 838 : Heads
# Toss 839 : Tails
# Toss 840 : Tails
# Toss 841 : Tails
# Toss 842 : Tails
# Toss 843 : Tails
# Toss 844 : Heads
# Toss 845 : Heads
# Toss 846 : Tails
# Toss 847 : Heads
# Toss 848 : Heads
# Toss 849 : Tails
# Toss 850 : Heads
# Toss 851 : Tails
# Toss 852 : Heads
# Toss 853 : Heads
# Toss 854 : Heads
# Toss 855 : Tails
# Toss 856 : Tails
# Toss 857 : Tails
# Toss 858 : Heads
# Toss 859 : Heads
# Toss 860 : Heads
# Toss 861 : Heads
# Toss 862 : Heads
# Toss 863 : Heads
# Toss 864 : Tails
# Toss 865 : Heads
# Toss 866 : Tails
# Toss 867 : Tails
# Toss 868 : Heads
# Toss 869 : Tails
# Toss 870 : Tails
# Toss 871 : Tails
# Toss 872 : Tails
# Toss 873 : Heads
# Toss 874 : Heads
# Toss 875 : Heads
# Toss 876 : Heads
# Toss 877 : Heads
# Toss 878 : Heads
# Toss 879 : Tails
# Toss 880 : Tails
# Toss 881 : Tails
# Toss 882 : Tails
# Toss 883 : Tails
# Toss 884 : Tails
# Toss 885 : Tails
# Toss 886 : Heads
# Toss 887 : Tails
# Toss 888 : Tails
# Toss 889 : Tails
# Toss 890 : Heads
# Toss 891 : Heads
# Toss 892 : Tails
# Toss 893 : Heads
# Toss 894 : Heads
# Toss 895 : Heads
# Toss 896 : Heads
# Toss 897 : Heads
# Toss 898 : Heads
# Toss 899 : Heads
# Toss 900 : Tails
# Toss 901 : Heads
# Toss 902 : Heads
# Toss 903 : Heads
# Toss 904 : Heads
# Toss 905 : Heads
# Toss 906 : Tails
# Toss 907 : Tails
# Toss 908 : Heads
# Toss 909 : Tails
# Toss 910 : Tails
# Toss 911 : Heads
# Toss 912 : Tails
# Toss 913 : Tails
# Toss 914 : Heads
# Toss 915 : Heads
# Toss 916 : Tails
# Toss 917 : Heads
# Toss 918 : Tails
# Toss 919 : Heads
# Toss 920 : Tails
# Toss 921 : Tails
# Toss 922 : Heads
# Toss 923 : Tails
# Toss 924 : Tails
# Toss 925 : Heads
# Toss 926 : Tails
# Toss 927 : Heads
# Toss 928 : Heads
# Toss 929 : Tails
# Toss 930 : Tails
# Toss 931 : Tails
# Toss 932 : Tails
# Toss 933 : Heads
# Toss 934 : Heads
# Toss 935 : Tails
# Toss 936 : Heads
# Toss 937 : Heads
# Toss 938 : Heads
# Toss 939 : Tails
# Toss 940 : Heads
# Toss 941 : Heads
# Toss 942 : Tails
# Toss 943 : Tails
# Toss 944 : Tails
# Toss 945 : Tails
# Toss 946 : Tails
# Toss 947 : Tails
# Toss 948 : Tails
# Toss 949 : Heads
# Toss 950 : Tails
# Toss 951 : Tails
# Toss 952 : Tails
# Toss 953 : Heads
# Toss 954 : Heads
# Toss 955 : Tails
# Toss 956 : Heads
# Toss 957 : Tails
# Toss 958 : Heads
# Toss 959 : Heads
# Toss 960 : Tails
# Toss 961 : Tails
# Toss 962 : Tails
# Toss 963 : Tails
# Toss 964 : Heads
# Toss 965 : Heads
# Toss 966 : Tails
# Toss 967 : Tails
# Toss 968 : Tails
# Toss 969 : Heads
# Toss 970 : Heads
# Toss 971 : Heads
# Toss 972 : Heads
# Toss 973 : Heads
# Toss 974 : Tails
# Toss 975 : Heads
# Toss 976 : Heads
# Toss 977 : Heads
# Toss 978 : Tails
# Toss 979 : Heads
# Toss 980 : Heads
# Toss 981 : Heads
# Toss 982 : Tails
# Toss 983 : Heads
# Toss 984 : Heads
# Toss 985 : Tails
# Toss 986 : Heads
# Toss 987 : Heads
# Toss 988 : Heads
# Toss 989 : Heads
# Toss 990 : Tails
# Toss 991 : Heads
# Toss 992 : Heads
# Toss 993 : Tails
# Toss 994 : Tails
# Toss 995 : Heads
# Toss 996 : Tails
# Toss 997 : Tails
# Toss 998 : Heads
# Toss 999 : Tails
# Toss 1000 : Tails
# ['Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'He ...
# 520480

# %% [markdown]
# Remember its a random experiment so the output will change everytime you run it. Here is the output sequence we'll use in this lesson:
# ```
# ['Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads']
# ```
# Considering its a random experiment, you can say that there has to be *some* underlying parameter for the outcome of a coin flip. Also, consider other random experiments with dice rolls. Can you identify a parameter that determines the outcome of such experiments?
#
# Parameter Inference is all to do with identifying that parameter with its optimal value. The first key step in this process is Maximum Likelihood Estimation (MLE).

# %% [markdown]
# ## Maximum Likelihood Estimation
#
# MLE primarily deals with **determining the parameters** that **maximize the probability of the data**. Such a determination can help you predict the outcome of future experiments e.g. If we Toss the coin 1 more time, what is the probability of seeing a Head?
#
# * It's a fair coin so the probability is 0.5.
#
# This is a safe assumption as it assumes independence between coin flips and hence past events have no impact on future ones.

# %%
p_head = lst.count("Heads")/10
p_head
# Out:
# 5.5

# %% [markdown]
# With both these approaches in hand, let's see which answer is more suitable by creating a general case from this example. You want to know the probability of 11th flip $ p_{11}(f_{11})$, being a head so you can write:
#
# > $p_{11}(f_{11}=Heads)$
#
# You can also write above for calculating the probability of $ith$ flip being a Head:
#
# > $p_i(f_i = Heads) = \theta_i$

# %% [markdown]
# Here $\theta_i$ is the parameter that governs the outcome of _ith_ flip. To signify that the probability distribution depends on $\theta_i$, you can use conditioning as you saw earlier and write down the last equation to show the probability distribution function along with its dependence on theta_i.
#
# > $p_i((f_i = Heads) | \theta_i)$
#
# *The probability of seeing heads in the ith flip , given theta_i*

# %% [markdown]
# This makes sense so far, but raises a few confusing points: If the data depends on theta parameter, then the first ten coin flips f_1 to f_10 depend on theta_1 to theta_10  for i = 1 to 10. So looking at the outcome of first ten experiments, how can we extrapolate it to theta_11?
#
#
# Here's how you can do this&mdash;if you say that random outcome of a sequence of flips is governed (or modeled) by the parameters theta_1 to theta_10, you can calculate the probability function based on observed data as:
#
# > $P (Heads, Heads, Tails, Tails, Tails, Heads, Tails, Heads, Heads, Heads) | \theta_{1}\theta_{2} .. \theta_{10})$

# %% [markdown]
# This is where Maximum Likelihood Estimation steps into the equation. The problem you have now is that you need to find values of thetas 1 to 10.  MLE helps find theta_i’s such that that probability function shown above is **as high as possible** and this is the basic principle of MLE.

# %% [markdown]
# #### Likelihood - The probability of data
#
# MLE looks at the probability of data and it tries to find those parameters (i.e. theta_1 through theta_10 in above case) that maximize the likelihood of this sequence occurring.
#
# > With maximum liklihood estimation, we want to choose those parameters under which our observations become most **likely**.

# %% [markdown]
# Going back to our coin flip example. If in our understanding, the coin flips do not affect each other, i.e., they are independent (the outcome of first flip does not affect the outcome of the second flip):
# >$P (H, H, T, T, T, H, T, H, H, H) | \theta_{1}\theta_{2} .. \theta_{10})$
#
# >$= P(F_1 = H | \theta_1).P(F_2 = H | \theta_2) .. P(F_{10} = H | \theta_{10})$
#
# >$= \prod_{i=1}^{10} p_i(F_i = f_i | \theta_i)$ - The general case for coin flip
#
# Note: $\prod$ signifies the product over a series, shown in the previous equation, just as $\Sigma$ denotes summation over a series.

# %% [markdown]
# ### MLE Assumptions
#
# Note here that the **independence assumption** allows you to simplify the complex likelihood term into ten simpler factors that can be shown through a general notation in the last equation.
#
# The independence assumption allows simplification of the likelihood term but you still don’t have theta_11 in the equation.
#
# There is another assumption you can introduce, based on the fact that the coin does not change significantly after each flip i.e.:
#
# * **The flips are quantitatively same, i.e., they are identically distributed**.
#
# This implies that the flips are taking place under similar circumstances, you can assume that the parameter governing the flips is one and same i.e. just the $\theta$ without any subscripts. Based on this assumption, you can rewrite above equation as :

# %% [markdown]
# >$\prod_{i=1}^{10} p_i(F_i = f_i | \theta_i) = \prod_{i=1}^{10} p(F_i = f_i | \theta) $

# %% [markdown]
# This assumption leads you to believe that the 10 flips are governed by the same parameter theta. You now have just one parameter governing the entire sequence of coin flips, and that includes the 11th flip as well.
#
# This is how MLE allows you to connect first 10 coin flips to the 11th coin flip and is the key for inference.

# %% [markdown]
# ### The two assumptions you made are used so often in Machine Learning that they have a special name together as an entity : "The i.i.d. assumption" i.e. Independent and Identically distributed samples.

# %% [markdown]
# This means that the 10 flips are independent and identically distributed which is great as it will allow you to explicitly write down the likelihood that you are trying to optimize.
#
# Remember that theta was defined as the probability of the flip showing up Heads; the probability of the sequence w.r.t. theta can now be formulated as:

# %% [markdown]
# $ \prod_{i=1}^{10} p(F_i = f_i | \theta)$
#
# $= \theta \theta (1-\theta)(1-\theta)(1-\theta) \theta(1-\theta)\theta\theta\theta$
#
# $=\theta^6(1-\theta)^4$
#
# * theta = Probability of seeing a head
# * 1 - theta = Probability of seeing a tail
# * The sequence:  H,H,T,T,T,H,T,H,H,H

# %% [markdown]
# You see here the i.i.d. assumptions simplifies  the likelihood function to a simple polynomial; to a point where you can **start optimizing the function for the parameter theta**.

# %% [markdown]
# This simplified polynomial expression can be interpreted as a function of theta i.e.,
# > $f(\theta)$
#
# Now you want to find out the maxima (maximum likelihood) of this function.
#
# <img src="images/der.png" width= "200">
#
#
# Following the intuition in the image above, you can achieve theta this by taking the derivative
# > $\frac{df}{d(\theta)}$
#
# Set this  zero, and solve for theta. Then verify the critical point i.e. maxima, by inserting it into the second derivative of f(theta). This is a simple approach, however, the application of product rule repeatedly in this process could be a technically challenging process. This calculation can be simplified using a monotonic function.
#
#
# ### Monotonic function
#
# > In mathematics, a monotonic function(or monotone function) is a function between ordered sets that preserves or reverses the given order. This concept first arose in calculus, and was later generalized to the more abstract setting of order theory. [Wiki](https://en.wikipedia.org/wiki/Monotonic_function)
#
#
#
# According to this theory, if you apply a monotonic function to another function , like the one you are trying to optimize above, this application will preserve the critical points (maxima in this case) of the original function. Logarithmic functions are normally used within the domain of machine learning to achieve the functionality of monotonicity  The logarithmic function is described as:
#
# > $log_b(x)$
#
# * where b is any number such that b > 0, b≠ 1, and x > 0.
# * The function is read "log base b of x".
#
# The logarithm y is the exponent to which b must be raised to get x. The behavior of a log function can be understood from following image.
#
#
# <img src="images/new_log.png" width="700">
#
#
# This helps you realize that **log of f(θ) i.e. log(f(θ)) will have the save maxima as the likelihood function f(θ).** This is better known as the **log likelihood**.
#
# Thus, the optimization function i.e. $\theta^6(1-\theta)^4$ , that you're trying to optimize w.r.t. theta can be written down as:
#
# >$\underset{\theta}{\operatorname{argmax}} \theta^6(1-\theta)^4$
#
# >In mathematics, the arguments of the maxima (abbreviated arg max or argmax) are the points of the domain of some function at which the function values are maximized
#
# Remember that you are not concerned with the actual maximum value of the function. You want to **learn the value for theta** where the **function has the maximum value**.
#
# Following the monotonicity principle, the argmax function can be written with natural log *ln* as:
#
# >$\underset{\theta}{\operatorname{argmax}} ln(\theta^6(1-\theta)^4)$
#
# > $=\underset{\theta}{\operatorname{argmax}} 6 (ln (\theta)) *4 (ln(1-\theta))$
#
# Let's call our log likelihood function $g(\theta)$, take its derivative and set it to zero.

# %% [markdown]
# > $ \frac{d}{d\theta}[g(\theta)] = |H|\frac{1}{\theta} + |T|\frac{1}{1-\theta}(-1)$
#
# |T| are the number of tails = 4
# |H| are the number of heads = 6
#
# You are simply solving for a general case here , so use |T| and |H|

# %% [markdown]
# > $|H|\frac{1}{\theta} + {|T|}\frac{1}{1-\theta}(-1) = 0 $

# %% [markdown]
# > $|H|(1-\theta) - |T|\theta = 0$
#
# > $\theta = \frac{|H|}{|H|+ |T|}$

# %% [markdown]
# This is the Maximum Likelihood Function $\theta_MLE$ for any given sequence of coins.
#
# $$\theta_{MLE} = \frac{|H|}{|H|+ |T|}$$
#
# For the initial problem, where H = 6  and T = 4, you get MLE for theta as 6/10 = 0.6 , or , 60% chance of seeing a head for the 11th coin given the data from first 10 coin flips.

# %% [markdown]
# > This maximum is called the **MLE for theta** as it makes the observed sequence **most likely**.

# %% [markdown]
# ## Limitations of MLE
#
# Consider a scenario where you get this sequence by total chance: [T,T,T,T,T]. According to the derived MLE formula, the probability of seeing a head at 6th coin toss would be zero. This demonstrates how MLE heavily depends on past data to find the likelihood function. It also indicates that MLE is only a first step for Parameter Estimation. We shall come across more sophisticated approaches like Maximum Aposteriori Estimate (MAP) and Fully Bayesian Analysis.

# %% [markdown]
# ## Additional Resources
# This section was pretty math heavy and included many new concepts like optimization, maximas and minimas, monotonicity and log functions. With that, take some time to go through following resources to see more example of MLE calculation and get a deep dive into the underlying mathematical theory.
#
# * [Probability Concepts Explained: Maximum Likelihood Estimation](https://towardsdatascience.com/probability-concepts-explained-maximum-likelihood-estimation-c7b4342fdbb1) - Example for calculating MLE with normal distributions.
# * [IID Statistics: Independent and Identically Distributed ](https://www.statisticshowto.datasciencecentral.com/iid-statistics/)
# * [Monotonically Increasing and Decreasing function: An algebraic approach](https://opencurriculum.org/5512/monotonically-increasing-and-decreasing-functions-an-algebraic-approach/)
# * [Logarithm Functions](https://mathbitsnotebook.com/Algebra2/Exponential/EXLogFunctions.html)

# %% [markdown]
# ## Summary
#
# In this lesson, you began to develop an intuition surrounding MLE. You saw how to use the principle of monotonicity to simplify complex probability calculations into simple arithmetic operations. You also looked at a simple example of a coin toss for MLE. You're well on your way to conducting further complex statistical experiments using Bayesian techniques!
